# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN

model = Sequential()
model.add(SimpleRNN(3, input_shape=(2,10)))
# model.add(SimpleRNN(3, input_length=2, input_dim=10))와 동일함.
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 3)                 42
#
# =================================================================
# Total params: 42 (168.00 Byte)
# Trainable params: 42 (168.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model = Sequential()
model.add(SimpleRNN(3, batch_input_shape=(8,2,10)))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (8, 3)                    42
#
# =================================================================
# Total params: 42 (168.00 Byte)
# Trainable params: 42 (168.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model = Sequential()
hidden_units =8
# model.add(SimpleRNN(hidden_units, input_length=10, input_dim=5, return_sequences=True))
model.add(SimpleRNN(hidden_units, batch_input_shape = (20,10,5), return_sequences=True))
model.add(SimpleRNN(hidden_units, return_sequences=True))
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_10 (SimpleRNN)   (20, 10, 8)               112
#
#  simple_rnn_11 (SimpleRNN)   (20, 10, 8)               136
#
# =================================================================
# Total params: 248 (992.00 Byte)
# Trainable params: 248 (992.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from keras import layers
from keras import activations
model = Sequential()
model.add(SimpleRNN(128, input_shape = (30,100), return_sequences=True))
model.add(layers.Dense(128, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_20 (SimpleRNN)   (None, 30, 128)           29312
#
#  dense (Dense)               (None, 30, 128)           16512
#
# =================================================================
# Total params: 45824 (179.00 KB)
# Trainable params: 45824 (179.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
